# %% [markdown]
# # **EJERCICIO I**
#
# ¿Cuál es la salida del algortimo que está acontinuación?
#
# * `n=4; k=2`
# *  `print(n)`
# *  `print(-n)`
# *  `print(n+k)`
# *  `print(k)`
# *  `print(n,k)`
# *  `print("")`
# *  `print("n%3.2g"%n)`
# *  `print("n*n=%3.2g"% n*n)`
# *  `print(n*n)`
# *  `print('n')`

# %% [markdown]
# # **EJERCICIO II**
#
# Encuentre el resultado para los siguientes segmentos de código:
#
#
#
# 1.   `x=3;`
#
#      `x=x+2;`
#
#      `print(x)`
# 2.   `y=-5.3;`
#
#      `y=y*7.0`
#
#      `print(y)`
# 3.   `x=8; y=3`
#
#      `x=x%y;`
#
#      `print(x)`

# %% [markdown]
# # **EJERCICIO III**
#
# ¿Cuál es el resultado, verdadero o falso, que se produce en el siguiente código por inspección y luego compruebe en la computadora?
#
#
#
#     x=8; y=5
#     a=1; b=2
#
# a.  `x==1 and a<=2 or y<x`
#
# b.  `(x==1 and a<=2) or y>x`
#
# c.  `x==1 and (a<=2 or y>x)`

# %% [markdown]
# # **EJERCICIO IV**
#
# Escriba un algoritmo que lea los datos: `7.0, 2.0, 8.3, 3.0, 5.6, 4.0` y calcule lo siguiente:
#
#
#
# a.  El mayor
#
# b.  El menor
#
# c.  La suma
#
# d.  La media

# %% [markdown]
# # **EJERCICIO V**
#
# * Si en la **UC** están podando árboles y cada rama tiene $P$ hojas, y a cada  árbol le quitaron $K$ ramas, ¿cuántos  ́arboles se deben podar para
# obtener $T$ hojas?
#
# * Si un amigo, no tan amigo, me presta $K$ pesos a $i$ pesos de interés
# diario, ¿cuánto le pagaré en una semana si el interés es simple?, ¿y
# cuánto si el interés es compuesto?

# %%
#Escribe código aquí

# %% [markdown]
# # **EJERCICIO VI**
#
# 1. Diseñe una función que calcule la cantidad de carne de aves en kilos
# si se tienen $N$ gallinas, $M$ gallos y $K$ pollitos cada uno pesando $6$
# kilos, $7$ kilos y $1$ kilo respectivamente.
#
# 2. El número de contagiados de Covid-19 en el país de NuncaLandia se
# duplica cada día. Hacer un programa que diga el número total de
# personas que se han contagiado cuando pasen $D$ días a partir de hoy,
# si el número de contagiados actuales es $C$.

# %%
#SOLUCION
N=GALLINAS
M=GALLOS
K=POLLOS

# %% [markdown]
# #**EJERCICIO VII**
# ### Calcular el Índice de masa corporal
# Utiliza las variables peso (kg) y estatura (m), para calcular el indice de masa muscular
#
# La fórmula es:
#
#
# $$imc = \frac{peso}{altura^2}$$
#
# ![texto alternativo](https://filesedc.com/uploads/150/img/2019/01/760/5c499e7cb28a0-5c499e7cb28de.webp)

# %%
#SOLUCION

# %%
23/()

# %% [markdown]
# #**EJERCICIO VIII**
#
# Utilizando variables declaradas en cadena de caracteres, imprima la frase: "Sumando 10 con 20 tenemos 30".

# %%
#SOLUCION
X=Sumando
P=10 
K=CON 
D=20
H=TENEMOS
J=30
Z=(X+P+K+D+H+J)
PRINT(Z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ebe507f5f790> in <module>()
#       1 #Escribe código aquí
# ----> 2 X=Sumando
#       3 P=10
#       4 K=CON
#       5 D=20
#
# NameError: name 'Sumando' is not defined

# %% [markdown]
# #**EJERCICIO IX**
#
# Investiga y explica cada uno de los siguientes conceptos usando un ejemplo de
# una capacidad humana:
#
# (1) Unidad central de procesamiento, (2) Memoria principal, (3) Memoria secundaria, (4) Dispositivos de entrada, y (5) Dispositivos de salida.
#
# Por ejemplo, “¿Cuál sería el equivalente humano de la Unidad central de
# procesamiento?”

# %%
#Escribe código aquí

# %% [markdown]
# #**EJERCICIO X**
#
# Escribir un programa que lea un entero porsitivo, $n$, introducido por el usuario y después muestre en pantalla la suma de todos los enteros desde 1 hasta $n$.

# %%
#Escribe código aquí

# %% [markdown]
# #**EJERCICIO XI**
#
# Considera el siguiente fragmento de código:
#
# ![image.png](data:image/png;base64,...)
#
# Una vez se hayan ejecutado todas las instrucciones,¿qué valor tendrá la variable_1?

# %%
#Escribe código aquí

# %% [markdown]
# #**EJERCICIO XII**
#
# Considera el siguiente fragmento de código:
#
# ![image.png](data:image/png;base64,...)
#
# Una vez se hayan ejecutado todas las instrucciones,¿qué valor tendrá la variable_3?

# %%
#Escribe código aquí

# %% [markdown]
# # **EJERCICIO XIII**
#
# El siguiente programa escrito en Python tiene como objetivo concatenar un nombre junto a un mensaje para imprimirlo por consola. Sin embargo, el siguiente programa contiene un error
#
# ![image.png](data:image/png;base64,...)
#
# Explique la línea en la que se encuentra el error, su naturaleza y cómo solucionarlo.

# %%
#Escribe código aquí

# %% [markdown]
# # **EJERCICIO XIV**
#
# *Caída Libre*
#
# **Descripción del problema**
#
# Crea una función que determine la velocidad, en (m/s), a la que viaja un objeto cuando toca el suelo, en caída libre. La función recibe la altura a la que se encontraba el objeto al soltarse, en metros.
#
# Como es caída libre, la velocidad inicial del objeto es de 0 m/s . Asume que la aceleración debido a la gravedad es de 9.8 m/s^2. Puedes usar la siguiente fórmula para calcular la velocidad final (vf), donde v0 es la velocidad inicial, a es la aceleración y d la distancia al suelo.
#
# ![image.png](data:image/png;base64,...)
#
# El valor retornado debe estar redondeado a dos decimales.
#
# *Ayuda*: El módulo 'math' puede ser de utilidad para la raíz cuadrada.
#
# Función requerida
#
# Tu solución debe tener una función de acuerdo con la siguiente especificación.
#
# ![image.png](data:image/png;base64,...)

# %%
#Escribe código aquí

# %% [markdown]
# # **EJERCICIO XV**
#
# *Edad de una persona*
#
# **Descripción del problema**
#
# Crea una función que calcule la edad de una persona a partir de su fecha de nacimiento y la fecha actual.
#
# Ambas fechas se proporcionan en años, meses y días, y la edad debe retornarse de la misma manera, en una cadena con la forma “aa,MM,dd”. Suponga que todos los meses son de 30 días.
#
# Por ejemplo, si Julieta Pérez nació el 20 de noviembre de 1986, y la fecha actual fuese el 16 de octubre de 1987, la función retornaría que la edad de Julieta es “0,10,26”, es decir, 0 años, 10 meses y 26 días.
#
# Función requerida
#
# Tu solución debe tener una función de acuerdo con la siguiente especificación.
#
# ![image.png](data:image/png;base64,...)

# %%
#Escribe código aquí
