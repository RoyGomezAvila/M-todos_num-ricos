# %% [markdown]
# # **EJERCICIOS**

# %% [markdown]
# 1. Determine lo propuesto por cada uno de los siguientes items, empleando las diferentes herramientas enunciadas en clase, principalmente la librería de [Python](https://www.python.org/) denominada [numpy](https://numpy.org/)
#
#
# 1.1. Resolver el sistema de ecuaciones:
#
# \begin{equation}
# \begin{pmatrix}
# 1 & 1 & 1 & 6 &\ \ \vert &11\\
# 2 & 3 & 6 & 19 &\ \ \vert &36\\
# 0 & 3 & 4 & 5 &\ \ \vert &28\\
# 1 & -1 & -1 & -6 &\ \ \vert & -12
# \end{pmatrix}
# \end{equation}
#
# 1.2. Averigüe el determinante de la matriz de coeficientes del sistema de ecuaciones anterior, a través de la instrucción `np.linalg.det`.
#
# 1.3. Crear un algoritmo en el que genere un arreglo aleatorio de valores de 0 a 100 con 60 valores, y este compruebe si el número es $53$ aparece en el arreglo o no.
#
# 1.4. Crear un tensor con valores de $0$ a $255$ al azar con forma $3\times3\times3$ e indicar su respectivo gráfico.

# %%
#Escribe código aquí.

# %% [markdown]
# 2. [La espiral logaritmica](https://en.wikipedia.org/wiki/Logarithmic_spiral) es una clase de espirales que aparecen de manera natural en diversas aplicaciones prácticas.  Esta espiral se puede generar a partir de las ecuaciones paramétricas:
#
# $$x(\theta)=e^{k\theta}\cos(\theta) \ \ \ \ \ \ \& \ \ \ \ \ \ y(\theta)=e^{k\theta}\sin(\theta),$$
#
# Considerando $k=0.005$ y $\theta$ en el rango de valores de  $-10\pi$  a  $10\pi$ con 2000 puntos, determina el gráfico de dicha espiral.

# %%
#Escribe código aquí.

# %% [markdown]
# 3. Emplea la libreria mathplotlib para realizar en un mismo recuadro el gráfico de las siguientes funciones:
#
#   *   $y_1(x)=e^{-x}\sin(x)$ en color morado.
#   *   $y_2(x)=e^{x}\cos(x)$ en color naranja.
#
# El dominio de estas gráficas debe ser de una entrada de $500$ datos en el intervalo $[-2\pi,2\pi]$.

# %%
#Escribe código aquí.

# %% [markdown]
# 4. Escribir una función que reciba un diccionario con las notas de los alumnos
# del curso en un examen y devuelva una serie con la nota mínima, la máxima, media y la desviación típica.
#
# | NOMBRE COMPLETO | 	CORTE 1 |
# | --------------- | ---------: |
# | ANDRADE, JOHN A.  | 	3,1 |
# | BELLO HERRERA, ERICK S.  | 1 |
# | BENITEZ, JASON A.  | 3,4 |
# | GOMEZ, HANDRELL D.  | 0 |
# | GUERRERO VASQUEZ, KEVIN M.  | 3,3 |
# | GUTIERREZ BONNHETT, NICOL M.  | 3,3 |
# | LOPEZ MONTAÑO, CARLOS S.  | 3,2 |
# | ORTIZ JIMENEZ, TOMAS A.  | 2,3 |
# | PRECIADO SARMIENTO, JHON S.  | 3,2 |
# | ROJAS RAMIREZ, INGRID J.  | 3,4 |
# | SULVARA CAMACHO, JUAN M.  | 3,7 |

# %%
#

# %% [markdown]
# 5. Escribe un programa que solicite una puntuación entre $0.0$ y $5.0$. Si la
# puntuación está fuera de ese rango, muestra un mensaje de error. Si la puntuación está entre $0.0$ y $5.0$, muestra la calificación usando la tabla siguiente:
#
# `Puntuación Calificación`\
# `>= 4.5 Sobresaliente`\
# `>= 4.0 Notable`\
# `>= 3.0 Bien`\
# `>= 2.0 Suficiente`\
# `< 1.0 Insuficiente`
#
# Ejecuta el programa repetidamente, para probar con varios valores de entrada diferentes.

# %% [markdown]
# 6. Escribir un programa que pregunte al usuario una cantidad a invertir, el interés porcentual anual y el número de años, y muestre por pantalla el capital obtenido en la inversión redondeado con dos decimales.

# %%
#Escribe código aquí.

# %% [markdown]
# 7. Escribir un programa de cálculo del salario para darle al empleado
# $1.5$ veces la tarifa horaria para todas las horas trabajadas que excedan de $40$ con la hora paga de $\$10$ dólares.

# %%
#Escribe código aquí.

# %% [markdown]
# 8. Crear un programa que realice la división entre dos números $a$ y $b$ de tal manera que contemplando la posibilidad de que el divisor sea cero.

# %%
#Escribe código aquí.

# %% [markdown]
# 9. Vamos a organizar una	lista	de	vehículos	en	un	diccionario	que	clasifica	estos	vehículos	de acuerdo	con	sus	primeras	letras.	Utiliza	la	lista	de	la	siguiente	celda	para resolver	el	problema.

# %%
carros	=	['Lamborghini',	'Versa',	'207_Sedan',	'Dodge_Charger',	'Aston_Martin',	'Pajero_TR4',	'Tiggo',	'Kangoo_Express',	'Mohave',	'Livina',	'207_SW',	'Palio_Adventure',	'Tucson',	'Doblò',	'500_Abarth',	'Jetta_Variant',	'Range_Rover_Evoque',	'Up!',	'Grand_Cherokee',	'HB20',	'Boxer',	'NX_200t',	'Bongo',	'RAM',	'Parati',	'Tiida_Hatch',	'CR-V',	'Boxster',	'Golf',	'308_CC',	'Fox',	'Z4_Roadster',	'Sandero',	'Polo_Sedan',	'Veloster',	'Cadillac',	'Ford_Edge',	'Discovery_4',	'EcoSport',	'Hilux',	'Logan',	'Gol_G4',	'Sorento',	'Santa_Fe',	'Vantage_Volante',	'Xsara_Picasso',	'Volkswagen',	'Crossfox',	'Touareg',	'Gallardo_LP_560_–_4',	'Optima',	'Jumper',	'Uno',	'J3',	'Edge',	'C3_Picasso',	'Voyage',	'Cayenne',	'Passat',	'Sonata',	'Aircross',	'Linea',	'Veracruz',	'Fit',	'Idea',	'A3',	'SpaceFox',	'New_Fiesta',	'DS',	'Ford_EcoSport',	'Jeep_Renegade',	'Accord']

# %% [markdown]
# *   Declara	un	diccionario	sin	contenido	(vació)	y	llámalo	de		`nombres_carros`.
#
# *   Construye	un	bucle		`for`		para	leer	cada	ítem	de	la	lista		carros.	Dentro	del	bucle	crea	una	variable llamada		`primera_letra`		y	almacena	en	ella	la	primera	letra	del	nombre	de	cada	vehículo.
#
# *  Ahora obtenga	un	diccionario, donde	las	**claves**	sean	las	letras	iniciales	de	los	nombres	de	los	vehículos	y	los	**valores**	una	lista	con
# los	nombres	de	todos	los	vehículos	iniciados	por	la	respectiva	letra.

# %%
#Escribe código aquí.

# %% [markdown]
# 10. En el centro recreativo lago grande, se encuentran realizando una Yincana entre varios equipos, y requiren saber qué jugador es el que más juegos ganó de forma consecutiva, de esta manera entregarle un trofeo a los mejores. Por tanto, requieren de una aplicación que reciba una cadena con las iniciales de los jugadores que ganaron en cada juego, separada por un espacio y que entregue una fila con los jugadores que ganaron al menos un juego y otra fila con el número de juegos ganados seguidos.
#
# **EJEMPLO:**
#
# **Entrada:** P P P J H T T T T K K T T S S S S P O F\
# **Salida:** P 3 J 1 H 1 T 4 K 2 T 2 S 4 P 1 O 1 F 1

# %%
#Escribe código aquí.
